# %%
import pandas as pd

# %%
header_names = [
    'duration', 
    'protocol_type', 
    'service', 
    'flag', 
    'src_bytes', 
    'dst_bytes', 
    'land', 
    'wrong_fragment', 
    'urgent', 
    'hot', 
    'num_failed_logins', 
    'logged_in', 
    'num_compromised', 
    'root_shell', 
    'su_attempted', 
    'num_root', 
    'num_file_creations', 
    'num_shells', 
    'num_access_files', 
    'num_outbound_cmds', 
    'is_host_login', 
    'is_guest_login', 
    'count', 
    'srv_count', 
    'serror_rate', 
    'srv_serror_rate', 
    'rerror_rate', 
    'srv_rerror_rate', 
    'same_srv_rate', 
    'diff_srv_rate', 
    'srv_diff_host_rate', 
    'dst_host_count', 
    'dst_host_srv_count', 
    'dst_host_same_srv_rate', 
    'dst_host_diff_srv_rate', 
    'dst_host_same_src_port_rate', 
    'dst_host_srv_diff_host_rate', 
    'dst_host_serror_rate', 
    'dst_host_srv_serror_rate', 
    'dst_host_rerror_rate', 
    'dst_host_srv_rerror_rate', 
    'attack_type', 
    'success_pred'
]

# %%
# !pwd
# Out:
# /home/limmireu/WorkSpaces/Network-traffic-analysis-study

# %%
DataSetKDDTrain = pd.read_csv("Datasets/KDD/KDDTrain+.csv", names=header_names)
DataSetKDDTest = pd.read_csv("Datasets/KDD/KDDTest+.csv", names=header_names)

# %%
DataSetKDDTrain
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 125968               0       0    0  ...                    0.10
# 125969               0       0    0  ...                    0.96
# 125970               0       0    0  ...                    0.12
# 125971               0       0    0  ...                    0.03
# 125972               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 125968                    0.06                         0.00
# 125969                    0.01                         0.01
# 125970                    0.06                         0.00
# 125971                    0.05                         0.00
# 125972                    0.03                         0.30
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 125968                         0.00                  1.00
# 125969                         0.00                  0.00
# 125970                         0.00                  0.72
# 125971                         0.00                  1.00
# 125972                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 125968                      1.00                  0.00
# 125969                      0.00                  0.00
# 125970                      0.00                  0.01
# 125971                      1.00                  0.00
# 125972                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  attack_type  success_pred
# 0                           0.00       normal            20
# 1                           0.00       normal            15
# 2                           0.00      neptune            19
# 3                           0.01       normal            21
# 4                           0.00       normal            21
# ...                          ...          ...           ...
# 125968                      0.00      neptune            20
# 125969                      0.00       normal            21
# 125970                      0.00       normal            18
# 125971                      0.00      neptune            20
# 125972                      0.00       normal            21
#
# [125973 rows x 43 columns]

# %%
DataSetKDDTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
#  12  num_compromised              125973 non-null  int64
#  13  root_shell                   125973 non-null  int64
#  14  su_attempted                 125973 non-null  int64
#  15  num_root                     125973 non-null  int64
#  16  num_file_creations           125973 non-null  int64
#  17  num_shells                   125973 non-null  int64
#  18  num_access_files             125973 non-null  int64
#  19  num_outbound_cmds            125973 non-null  int64
#  20  is_host_login                125973 non-null  int64
#  21  is_guest_login               125973 non-null  int64
#  22  count                        125973 non-null  int64
#  23  srv_count                    125973 non-null  int64
#  24  serror_rate                  125973 non-null  float64
#  25  srv_serror_rate              125973 non-null  float64
#  26  rerror_rate                  125973 non-null  float64
#  27  srv_rerror_rate              125973 non-null  float64
#  28  same_srv_rate                125973 non-null  float64
#  29  diff_srv_rate                125973 non-null  float64
#  30  srv_diff_host_rate           125973 non-null  float64
#  31  dst_host_count               125973 non-null  int64
#  32  dst_host_srv_count           125973 non-null  int64
#  33  dst_host_same_srv_rate       125973 non-null  float64
#  34  dst_host_diff_srv_rate       125973 non-null  float64
#  35  dst_host_same_src_port_rate  125973 non-null  float64
#  36  dst_host_srv_diff_host_rate  125973 non-null  float64
#  37  dst_host_serror_rate         125973 non-null  float64
#  38  dst_host_srv_serror_rate     125973 non-null  float64
#  39  dst_host_rerror_rate         125973 non-null  float64
#  40  dst_host_srv_rerror_rate     125973 non-null  float64
#  41  attack_type                  125973 non-null  object
#  42  success_pred                 125973 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 41.3+ MB

# %%
print(len(set(DataSetKDDTrain["protocol_type"])))
print(set(DataSetKDDTrain["protocol_type"]))
# Out:
# 3
# {'udp', 'icmp', 'tcp'}

# %%
print(len(set(DataSetKDDTrain["service"])))
print(set(DataSetKDDTrain["service"]))
# Out:
# 70
# {'whois', 'ftp', 'netbios_ssn', 'ldap', 'nntp', 'urh_i', 'imap4', 'harvest', 'vmnet', 'ftp_data', 'ecr_i', 'echo', 'daytime', 'http_2784', 'ctf', 'csnet_ns', 'time', 'domain_u', 'link', 'http_443', 'printer', 'mtp', 'uucp_path', 'bgp', 'discard', 'nnsp', 'ssh', 'rje', 'uucp', 'http_8001', 'systat', 'supdup', 'exec', 'eco_i', 'domain', 'urp_i', 'efs', 'pop_2', 'private', 'kshell', 'X11', 'hostnames', 'shell', 'netbios_ns', 'IRC', 'klogin', 'smtp', 'sunrpc', 'ntp_u', 'remote_job', 'login', 'pop_3', 'pm_dump', 'courier', 'red_i', 'aol', 'auth', 'other', 'iso_tsap', 'telnet', 'http', 'name', 'netbios_dgm', 'tftp_u', 'finger', 'gopher', 'Z39_50', 'sql_net', 'netstat', 'tim_i'}

# %%
print(len(set(DataSetKDDTrain["flag"])))
print(set(DataSetKDDTrain["flag"]))
# Out:
# 11
# {'RSTR', 'OTH', 'SF', 'S3', 'SH', 'S1', 'S2', 'RSTOS0', 'S0', 'REJ', 'RSTO'}

# %%
print(len(set(DataSetKDDTrain["attack_type"])))
print(set(DataSetKDDTrain["attack_type"]))
# Out:
# 23
# {'teardrop', 'pod', 'nmap', 'phf', 'normal', 'ftp_write', 'buffer_overflow', 'ipsweep', 'portsweep', 'satan', 'back', 'spy', 'neptune', 'multihop', 'rootkit', 'imap', 'guess_passwd', 'land', 'smurf', 'loadmodule', 'warezclient', 'warezmaster', 'perl'}

# %%
for Test in list(set(DataSetKDDTest["attack_type"])):
    index = DataSetKDDTrain["attack_type"].str.contains(Test)
    num = len(DataSetKDDTrain[index])
    print(f"{Test}: {num}")
# Out:
# saint: 0
# mscan: 0
# teardrop: 892
# pod: 201
# xlock: 0
# nmap: 1493
# xterm: 0
# ps: 3599
# snmpgetattack: 0
# phf: 4
# processtable: 0
# sendmail: 0
# normal: 67343
# sqlattack: 0
# ftp_write: 8
# apache2: 0
# buffer_overflow: 30
# worm: 0
# ipsweep: 3599
# named: 0
# udpstorm: 0
# portsweep: 2931
# satan: 3633
# back: 956
# mailbomb: 0
# neptune: 41214
# httptunnel: 0
# multihop: 7
# rootkit: 10
# imap: 11
# guess_passwd: 53
# snmpguess: 0
# xsnoop: 0
# land: 18
# smurf: 2646
# loadmodule: 9
# warezmaster: 20
# perl: 3

# %%
for Train in list(set(DataSetKDDTrain["attack_type"])):
    index = DataSetKDDTrain["attack_type"].str.contains(Train)
    num = len(DataSetKDDTrain[index])
    print(f"{Train}: {num}")
# Out:
# teardrop: 892
# pod: 201
# nmap: 1493
# phf: 4
# normal: 67343
# ftp_write: 8
# buffer_overflow: 30
# ipsweep: 3599
# portsweep: 2931
# satan: 3633
# back: 956
# spy: 2
# neptune: 41214
# multihop: 7
# rootkit: 10
# imap: 11
# guess_passwd: 53
# land: 18
# smurf: 2646
# loadmodule: 9
# warezclient: 890
# warezmaster: 20
# perl: 3

# %%
header_names = [
    'duration', 
    'protocol_type', 
    'service', 
    'flag', 
    'src_bytes', 
    'dst_bytes', 
    'land', 
    'wrong_fragment', 
    'urgent', 
    'hot', 
    'num_failed_logins', 
    'logged_in', 
    'num_compromised', 
    'root_shell', 
    'su_attempted', 
    'num_root', 
    'num_file_creations', 
    'num_shells', 
    'num_access_files', 
    'num_outbound_cmds', 
    'is_host_login', 
    'is_guest_login', 
    'count', 
    'srv_count', 
    'serror_rate', 
    'srv_serror_rate', 
    'rerror_rate', 
    'srv_rerror_rate', 
    'same_srv_rate', 
    'diff_srv_rate', 
    'srv_diff_host_rate',
    'dst_host_count',
    'dst_host_srv_count', 
    'dst_host_same_srv_rate',
    'dst_host_diff_srv_rate', 
    'dst_host_same_src_port_rate',
    'dst_host_srv_diff_host_rate',
    'dst_host_serror_rate', 
    'dst_host_srv_serror_rate', 
    'dst_host_rerror_rate', 
    'dst_host_srv_rerror_rate', 
    'attack_type',
    'success_pred'
]

# %%
header_names[4:6]
# Out:
# ['src_bytes', 'dst_bytes']

# %%
import os

dataset_root = os.path.join(os.getcwd(),'Datasets/KDD')
train_file = os.path.join(dataset_root, 'KDDTrain+.csv')

# %%
import pandas as pd
train_df = pd.read_csv(train_file, names=header_names)

# %%
train_df["num_outbound_cmds"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 125968    0
# 125969    0
# 125970    0
# 125971    0
# 125972    0
# Name: num_outbound_cmds, Length: 125973, dtype: int64

# %%
list(train_df["attack_type"])
# Out:
# ['normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'warezclient',
#  'neptune',
#  'neptune',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'teardrop',
#  'normal',
#  'warezclient',
#  'neptune',
#  'normal',
#  'neptune',
#  'teardrop',
#  'normal',
#  'normal',
#  'normal',
#  'nmap',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'satan',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'teardrop',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'smurf',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'nmap',
#  'normal',
#  'warezclient',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'portsweep',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'smurf',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'satan',
#  'satan',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'teardrop',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'warezclient',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'satan',
#  'pod',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'warezclient',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'teardrop',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'neptune',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'portsweep',
#  'nmap',
#  'smurf',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'portsweep',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'nmap',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'warezclient',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'smurf',
#  'ipsweep',
#  'satan',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'portsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'portsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'satan',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'ipsweep',
#  'back',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'portsweep',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'satan',
#  'teardrop',
#  'normal',
#  'smurf',
#  'normal',
#  'normal',
#  'ipsweep',
#  'normal',
#  'smurf',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'smurf',
#  'teardrop',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'back',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'satan',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'warezclient',
#  'ipsweep',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'neptune',
#  'satan',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'warezclient',
#  'ipsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'smurf',
#  'neptune',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'warezclient',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'portsweep',
#  'neptune',
#  'back',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'normal',
#  'back',
#  'normal',
#  'portsweep',
#  'portsweep',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'portsweep',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'satan',
#  'satan',
#  'normal',
#  'normal',
#  'neptune',
#  'teardrop',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'back',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'guess_passwd',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'teardrop',
#  'neptune',
#  'normal',
#  'neptune',
#  'satan',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'warezclient',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'smurf',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'smurf',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'back',
#  'portsweep',
#  'neptune',
#  'teardrop',
#  'ipsweep',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'warezclient',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'portsweep',
#  'warezclient',
#  'portsweep',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'smurf',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'portsweep',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'ipsweep',
#  'normal',
#  'normal',
#  'satan',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'satan',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'smurf',
#  'teardrop',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'satan',
#  'normal',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'normal',
#  'nmap',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'smurf',
#  'nmap',
#  'portsweep',
#  'neptune',
#  'satan',
#  'normal',
#  'portsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'portsweep',
#  'smurf',
#  'neptune',
#  'neptune',
#  'neptune',
#  'nmap',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'ipsweep',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'smurf',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'satan',
#  'normal',
#  'neptune',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'smurf',
#  'normal',
#  'smurf',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'neptune',
#  'normal',
#  'neptune',
#  'normal',
#  'ipsweep',
#  'neptune',
#  'normal',
#  'neptune',
#  'portsweep',
#  'neptune',
#  'neptune',
#  'normal',
#  'normal',
#  'neptune',
#  'neptune',
#  'normal',
#  ...]

# %%
map_att_type = DataSetKDDTrain["protocol_type"]
len(map_att_type)
# Out:
# 125973

# %%
for j in zip(range(len(set(DataSetKDDTrain["protocol_type"]))), list(set(DataSetKDDTrain["protocol_type"]))):
    DataSetKDDTrain.loc[(DataSetKDDTrain['protocol_type'] == j[1]), "protocol_type"] = j[0]

for j in zip(range(len(set(DataSetKDDTrain["service"]))), list(set(DataSetKDDTrain["service"]))):
    DataSetKDDTrain.loc[(DataSetKDDTrain['service'] == j[1]), "service"] = j[0]
    
for j in zip(range(len(set(DataSetKDDTrain["flag"]))), list(set(DataSetKDDTrain["flag"]))):
    DataSetKDDTrain.loc[(DataSetKDDTrain['flag'] == j[1]), "flag"] = j[0]

# %%
DataSetKDDTrain
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0             2       9    2        491          0     0
# 1              0             0      57    2        146          0     0
# 2              0             2      38    8          0          0     0
# 3              0             2      60    2        232       8153     0
# 4              0             2      60    2        199        420     0
# ...          ...           ...     ...  ...        ...        ...   ...
# 125968         0             2      38    8          0          0     0
# 125969         8             0      38    2        105        145     0
# 125970         0             2      46    2       2231        384     0
# 125971         0             2      45    8          0          0     0
# 125972         0             2       9    2        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 125968               0       0    0  ...                    0.10
# 125969               0       0    0  ...                    0.96
# 125970               0       0    0  ...                    0.12
# 125971               0       0    0  ...                    0.03
# 125972               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 125968                    0.06                         0.00
# 125969                    0.01                         0.01
# 125970                    0.06                         0.00
# 125971                    0.05                         0.00
# 125972                    0.03                         0.30
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 125968                         0.00                  1.00
# 125969                         0.00                  0.00
# 125970                         0.00                  0.72
# 125971                         0.00                  1.00
# 125972                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 125968                      1.00                  0.00
# 125969                      0.00                  0.00
# 125970                      0.00                  0.01
# 125971                      1.00                  0.00
# 125972                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  attack_type  success_pred
# 0                           0.00       normal            20
# 1                           0.00       normal            15
# 2                           0.00      neptune            19
# 3                           0.01       normal            21
# 4                           0.00       normal            21
# ...                          ...          ...           ...
# 125968                      0.00      neptune            20
# 125969                      0.00       normal            21
# 125970                      0.00       normal            18
# 125971                      0.00      neptune            20
# 125972                      0.00       normal            21
#
# [125973 rows x 43 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 range(0.05, 0.005)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
mylist
